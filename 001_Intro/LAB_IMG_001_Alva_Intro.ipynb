# %%
# !pip install scikit-image watermark -q
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 20.5 MB/s eta 0:00:00

# %%
#El código generado puede estar sujeto a licencia
import numpy as np
import cv2
from cv2 import imread
import matplotlib.pyplot as plt

# %%
# %load_ext watermark
# %watermark
# %watermark --iversions
# Out:
# Last updated: 2025-06-22T22:05:25.687505+00:00
#
# Python implementation: CPython
# Python version       : 3.11.13
# IPython version      : 7.34.0
#
# Compiler    : GCC 11.4.0
# OS          : Linux
# Release     : 6.1.123+
# Machine     : x86_64
# Processor   : x86_64
# CPU cores   : 2
# Architecture: 64bit
#
# numpy     : 2.0.2
# cv2       : 4.11.0
# matplotlib: 3.10.0

# %% [markdown]
# ## Input

# %%
# !wget https://d1lfxha3ugu3d4.cloudfront.net/images/opencollection/archives/size2/S03i3165l01.jpg
#https://scikit-image.org/docs/stable/api/skimage.data.html#skimage.data.coins
#https://opencollection.brooklynmuseum.org/archives/image/51611
# Out:
# --2025-06-22 22:05:25--  https://d1lfxha3ugu3d4.cloudfront.net/images/opencollection/archives/size2/S03i3165l01.jpg
# Resolving d1lfxha3ugu3d4.cloudfront.net (d1lfxha3ugu3d4.cloudfront.net)... 18.239.229.60, 18.239.229.16, 18.239.229.96, ...
# Connecting to d1lfxha3ugu3d4.cloudfront.net (d1lfxha3ugu3d4.cloudfront.net)|18.239.229.60|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 30340 (30K) [image/jpeg]
# Saving to: ‘S03i3165l01.jpg’
#
# S03i3165l01.jpg     100%[===================>]  29.63K  --.-KB/s    in 0.02s
#
# 2025-06-22 22:05:26 (1.20 MB/s) - ‘S03i3165l01.jpg’ saved [30340/30340]

# %% [markdown]
# ## Leer imagenes

# %%
img = imread('S03i3165l01.jpg')
plt.imshow(img)
plt.show()

# %% [markdown]
# ## Funcion

# %%
def data_img(img):
  print('Tamaño = ',img.shape)
  print('Max = ',np.max(img))
  print('Min = ',np.min(img))

data_img(img)
# Out:
# Tamaño =  (303, 384, 3)
# Max =  252
# Min =  1

# %% [markdown]
# ## Recortar

# %%
# Primero alto, después ancho
img_cropped = img[0:80, 300:370]
plt.imshow(img_cropped)

# %%
# Primero alto, después ancho
img_cropped = img[150:220, 310:384]
plt.imshow(img_cropped)

# %%
RGB = (0, 0, 0) #negro ausencia de color
RGB = (255, 255, 255) #blanco
M = (0) #monocromo

# %% [markdown]
# ## Selección del primer canal de color

# %%
X = img_cropped[:,:,0]
data_img(X)
# Out:
# Tamaño =  (70, 74)
# Max =  218
# Min =  12

# %%
plt.imshow(X,cmap='gray')
plt.show()

# %%
data_img(img_cropped)
# Out:
# Tamaño =  (70, 74, 3)
# Max =  218
# Min =  12

# %%
img = imread('S03i3165l01.jpg')
plt.imshow(img)
plt.show()

# %%
# Primero ancho y despues alto
img_resize = cv2.resize(img_cropped, (60, 60))
plt.imshow(img_resize)

# %%
# Apilado vertical
ver = np.vstack((img_resize, img_resize))
plt.imshow(ver);

# %%
# Primero ancho y despues alto
img_resize = cv2.resize(img_cropped, (60, 60))
plt.imshow(img_resize)

# %% [markdown]
# ## Me da informacion del color (ojo es BGR)

# %%
img_cropped[0:0]
# Out:
# array([], shape=(0, 74, 3), dtype=uint8)

# %%
X[0:0]
# Out:
# array([], shape=(0, 74), dtype=uint8)

# %%
pixel1 = (255,0,0)
pixel2 = (0,255,0)
pixel3 = (0,0,255)

# %%
plt.imshow([[pixel1,pixel2,pixel3,]])

# %%
# !wget https://www2.eecs.berkeley.edu/Research/Projects/CS/vision/bsds/BSDS300/html/images/plain/normal/color/198023.jpg
# Out:
# --2025-06-22 22:05:28--  https://www2.eecs.berkeley.edu/Research/Projects/CS/vision/bsds/BSDS300/html/images/plain/normal/color/198023.jpg
# Resolving www2.eecs.berkeley.edu (www2.eecs.berkeley.edu)... 128.32.244.190
# Connecting to www2.eecs.berkeley.edu (www2.eecs.berkeley.edu)|128.32.244.190|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 39350 (38K) [image/jpeg]
# Saving to: ‘198023.jpg’
#
# 198023.jpg          100%[===================>]  38.43K  --.-KB/s    in 0.07s
#
# 2025-06-22 22:05:28 (544 KB/s) - ‘198023.jpg’ saved [39350/39350]

# %%
img = imread('/content/blue_girl.jpg')
plt.imshow(img)
plt.show()

# %%
img[0:0]
# Out:
# array([], shape=(0, 683, 3), dtype=uint8)

# %%
pixel1 = (420,250,3)

# %%
plt.imshow([[pixel1]])
# Out:
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [3..420].

# %%
# Convert the image to grayscale
gray_img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

# Apply Canny edge detection
img_canny = cv2.Canny(gray_img, 100, 200)

plt.imshow(img_canny, cmap='gray')
plt.title('Canny Edge Detection')
plt.show()
